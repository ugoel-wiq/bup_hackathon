# %%
import pandas as pd
from google.cloud import bigquery
import json
import auth
import requests
import subprocess
import pandas as pd
import numpy as np
import logging 
import warnings
from google.cloud import bigquery
from prophet import Prophet
import logging
from concurrent.futures import ThreadPoolExecutor, as_completed


warnings.filterwarnings("ignore", category=DeprecationWarning, message=".*__init__.*")
logging.getLogger('cmdstanpy').setLevel(logging.WARNING)

product_retrieval_endpoint = "https://australia-southeast1-aiplatform.googleapis.com/v1/projects/639471061669/locations/us-central1/endpoints/8303344687196930048:predict"

# Get Google Cloud Access Token
def get_gcloud_access_token():
    try:
        # Run the gcloud command to get the access token
        result = subprocess.run(
            ['gcloud', 'auth', 'print-access-token'],
            stdout=subprocess.PIPE,
            stderr=subprocess.PIPE,
            check=True
        )
        
        # Decode the output to get the token as a string
        access_token = result.stdout.decode('utf-8').strip()
        
        return access_token
    except subprocess.CalledProcessError as e:
        # Handle errors in the subprocess call
        print(f"An error occurred: {e.stderr.decode('utf-8')}")
        return None

# Call Cold Start Model and retrieve the top 3 (default) most similar produts
def get_retrieval_produts (kws,top_n=1000,score_threshold=0.5): #CHECK THIS
    
    # Get the access token
    token = get_gcloud_access_token()
    bearer_token = 'Bearer ' + token
    
    converted_kw = [{"term": kw} for kw in kws]
    
    payload = json.dumps({
    "instances": converted_kw,
    "parameters": {"max_results": top_n}
    })
    
    headers = {
        'Authorization': bearer_token,
        'Content-Type': 'application/json'
    }
    
    response = requests.request("POST", product_retrieval_endpoint, headers=headers, data=payload)
    
    if response.status_code == 200:
        data = response.json()
        results = pd.DataFrame.from_records(data['predictions']).explode(['scores','articles'])\
                .reset_index(drop=True).rename(columns = {'articles':'product_nbr', 'keyword':'kw'})
        
        
        results = results[results['scores'] >= score_threshold]
        return results

# %%
## Reading Facets data
facets = pd.read_csv("facets_b2c.csv")

# %%
search_phrases = dict(facets.SearchPhrase)
facet_names = facets.FacetDisplayName

# %%
result_dict = facets.groupby('SearchPhrase')['FacetDisplayName'].apply(list).to_dict()
result_dict
# Out:
# {'BABY ACCESSORIES': ['Wipes',
#   'Bottles',
#   'Teething & Soothers',
#   'Bath & Skincare',
#   'Baby Health & Safety',
#   'Baby Toys',
#   'Baby Bibs'],
#  'BABY FORMULA': ['0 - 6 months', '6-12 months', '12 months plus'],
#  'BACON': ['Diced Bacon', 'Streaky Bacon', 'Shortcut Bacon', 'Middle Bacon'],
#  'BAKING': ['Pancake Mix',
#   'Chocolate Chips',
#   'Cooking Chocolate',
#   'Bread Mix',
#   'Brownie Mix',
#   'Cookie Mix',
#   'Muffin Mix',
#   'Cake Decorations',
#   'Colours & Essences'],
#  'BISCUITS': ['Crackers',
#   'Cookies',
#   'Chocolate Biscuits',
#   'Shortbread',
#   'Crispbread',
#   'Wafer Biscuits'],
#  'BREAD': ['White Bread',
#   'Wholegrain Bread',
#   'Turkish Bread',
#   'Banana Bread',
#   'Raisin Toast'],
#  'BUTTER': ['Butter & Margarine',
#   'Unsalted Butter',
#   'Salted Butter',
#   'Spreadable Butter'],
#  'Baby': ['Wipes',
#   'Baby Food',
#   'Nappies',
#   'Nappy Pants',
#   'Baby & Toddler Snacks',
#   'Baby Formula'],
#  'Baby Food': ['Organic Food',
#   'Baby Food 4 Months+',
#   'Baby Food 6 Months+',
#   'Baby Food 8 Months+',
#   'Baby & Toddler Snacks',
#   'Baby Formula'],
#  'Beef': ['Mince', 'Steak', 'Diced & Strips', 'Sausages & Burgers', 'Stock'],
#  'Biscuits': ['Multipacks'],
#  'Bread': ['Bread Rolls', 'Garlic Bread'],
#  'Butter': ['Nut Butters'],
#  'CEREAL': ['Oats', 'Bran'],
#  'CHEESE': ['Cheese Slices',
#   'Cream Cheese',
#   'Cheese Block',
#   'Cottage Cheese',
#   'Snacking Cheese',
#   'Shredded Cheese',
#   'Light Cheese'],
#  'CHICKEN': ['Chicken Breast',
#   'Chicken Thigh',
#   'Chicken Mince',
#   'Chicken Tenders',
#   'Chicken Nuggets',
#   'Chicken Wings',
#   'Chicken Drumsticks',
#   'Chicken Kebabs',
#   'Chicken Kievs'],
#  'CHIPS': ['Frozen Chips', 'Corn Chips', 'Potato Chips'],
#  'COFFEE': ['Coffee Pods',
#   'Coffee Beans',
#   'Instant Coffee',
#   'Coffee Sachets',
#   'Ground Coffee',
#   'Decaf Coffee'],
#  'CREAM': ['Sour Cream', 'Whipped Cream', 'Cooking Cream'],
#  'Cake': ['Cake Mix',
#   'Birthday Cake',
#   'Mud Cake',
#   'Chocolate Cake',
#   'Cheesecake',
#   'Sponge Cake',
#   'Cupcake'],
#  'Cakes': ['Cake Mix',
#   'Birthday Cake',
#   'Mud Cake',
#   'Chocolate Cake',
#   'Cheesecake',
#   'Sponge Cake',
#   'Cupcake'],
#  'Chips': ['Multipack'],
#  'Chocolate': ['Chocolate Blocks',
#   'Chocolate Bars',
#   'Boxed Chocolate',
#   'Chocolate Minis',
#   'Dark Chocolate',
#   'Milk Chocolate',
#   'Chocolate Share Packs',
#   'Cooking Chocolate',
#   'Gift Packs'],
#  'Christmas': ['Decorations',
#   'Chocolate',
#   'Stocking & Advent Calendars',
#   'Pudding',
#   'Cake',
#   'Candy Canes & Lollies',
#   'Christmas Lights',
#   'Christmas Tree',
#   'Ham'],
#  'Coffee': ['Specialty'],
#  'EGGS': ['6 Pack', '12 Pack', 'Family Pack'],
#  'Eggs': ['Free Range'],
#  'FLOUR': ['Plain Flour',
#   'Self Raising Flour',
#   'Wholemeal Flour',
#   'Spelt Flour'],
#  'Frozen Meals': ['Pasta',
#   'Beef',
#   'Chicken',
#   'Kids Meals',
#   'Pies',
#   'Asian',
#   'Pies & Sausage Rolls',
#   'Pizza',
#   'Single Serve Meals'],
#  'HAM': ['Shaved & Shredded Ham',
#   'Sliced Ham',
#   'Deli Ham',
#   'Leg Ham',
#   'Champagne Ham',
#   'Honey Ham',
#   'Smoked Ham',
#   'English Ham'],
#  'ICECREAM': ['Icecream Cones & Sticks',
#   'Vanilla',
#   'Chocolate',
#   'Strawberry',
#   'Icecream Tubs'],
#  'Ice Cream': ['Vanilla Ice Cream',
#   'Chocolate Ice Cream',
#   'Ice Cream Cones',
#   'Ice Cream Tubs',
#   'Ice Cream Cakes',
#   'Sandwiches',
#   'Minis & Bites'],
#  'JUICE': ['Fruit Juice', 'Juice Poppers', 'Vegetable Juice'],
#  'LOLLIES': ['Sour Lollies', 'Liquorice'],
#  'Lollies': ['Snakes', 'Party Mix', 'Family Size', 'Lollipops'],
#  'MILK': ['Almond Milk',
#   'Coconut Milk',
#   'Oat Milk',
#   'Skim Milk',
#   'Condensed Milk',
#   'Rice Milk',
#   'Full Fat'],
#  'MINCE': ['Beef Mince',
#   'Pork Mince',
#   'Chicken Mince',
#   'Turkey Mince',
#   'Lean Beef Mince'],
#  'Mayonaise': ['Whole Egg', 'Japanese', 'Light', 'Aioli', 'Traditional'],
#  'Meals': ['Pasta',
#   'Beef',
#   'Chicken',
#   'Soup',
#   'Quiche',
#   'Family Meals',
#   'Pizza',
#   'Single Serve Meals',
#   'Pies'],
#  'Milk': ['Long Life'],
#  'Nappies': ['Bundles',
#   'Newborn',
#   'Size 2',
#   'Size 3',
#   'Size 4',
#   'Size 5',
#   'Size 6',
#   'Nappy Pants',
#   'Swim Nappies',
#   'Night Time Nappies'],
#  'Noodles': ['Cup',
#   'Instant',
#   'Vermicelli & Rice Noodles',
#   'Udon Noodles',
#   'Ramen Noodles'],
#  'OATS': ['Muesli',
#   'Granola',
#   'Rolled Oats',
#   'Quick Oats',
#   'Clusters',
#   'Oat Sachets'],
#  'Oil': ['Olive Oil',
#   'Vegetable Oil',
#   'Canola Oil',
#   'Flavoured',
#   'Spray',
#   'Sesame Oil',
#   'Peanut Oil',
#   'Rice Bran Oil',
#   'Coconut Oil'],
#  'PASTA': ['Pasta Sauce', 'Fresh Pasta'],
#  'PIZZA': ['Pizza Base', 'Pizza Sauce', 'Frozen Pizza'],
#  'Pasta': ['Spaghetti',
#   'Spiral',
#   'Penne',
#   'Fettuccine',
#   'Macaroni',
#   'Rigatoni'],
#  'RICE': ['Brown Rice',
#   'Basmati Rice',
#   'Jasmine Rice',
#   'Microwave Rice',
#   'White Rice',
#   'Long Grain Rice'],
#  'Ready To Eat Meals': ['Pasta',
#   'Beef',
#   'Chicken',
#   'Soup',
#   'Quiche',
#   'Family Meals',
#   'Pizza',
#   'Single Serve Meals',
#   'Pies'],
#  'Rice': ['Vegetable Rice'],
#  'SAUSAGES': ['Beef Sausages', 'Pork Sausages', 'Chicken Sausages'],
#  'SPREADS': ['Peanut Butter',
#   'Honey',
#   'Jam',
#   'Cheese Spread',
#   'Sweet Spreads'],
#  'SUGAR': ['White Sugar',
#   'Brown Sugar',
#   'Raw Sugar',
#   'Icing Sugar',
#   'Caster Sugar'],
#  'Sauce': ['Pasta sauce',
#   'Tomato sauce',
#   'Soy Sauce',
#   'BBQ Sauce',
#   'Hot Sauce'],
#  'Sausages': ['Chipolatas', 'Frankfurts & Hotdogs'],
#  'Soap': ['Soap Refil', 'Body Wash', 'Soap Bars', 'Liquid'],
#  'Soft Drink': ['Bulk'],
#  'Soup': ['Tomato Soup',
#   'Instant Soup',
#   'Chicken Soup',
#   'Pumpkin Soup',
#   'French Onion Soup',
#   'Canned Soup',
#   'Miso',
#   'Vegetable'],
#  'Toilet Paper': ['Double Length', 'Recycled'],
#  'Toothbrush': ['Electric Toothbrush',
#   'Kids Toothbrush',
#   'Soft Bristles',
#   'Medium Bristles'],
#  'Toothpaste': ['Whitening', 'Kids', 'Sensitive'],
#  'WATER': ['Mineral Water', 'Bottled Water', 'Flavoured Water'],
#  'Water': ['Bulk'],
#  'Wipes': ['Bundles'],
#  'YOGHURT': ['Greek Yoghurt', 'Yoghurt Pouches'],
#  'Yoghurt': ['Vanilla Yoghurt',
#   'Gut Health',
#   'Protein Yoghurt',
#   'Kids Yoghurt',
#   'Dairy Free Yoghurt'],
#  'bakery': ['Bread',
#   'Wraps',
#   'Cakes',
#   'Donuts & Cookies',
#   'Muffins',
#   'Pastries & Desserts'],
#  'beans': ['Green Beans',
#   'Black Beans',
#   'Baked Beans',
#   'Frozen Beans',
#   'Kidney Beans',
#   'Chickpeas',
#   'Lentils'],
#  'cake mix': ['Cupcake Mix',
#   'Cookie Mix',
#   'Muffin Mix',
#   'Brownie Mix',
#   'Chocolate Cake Mix',
#   'Vanilla Cake Mix'],
#  'cat': ['Cat Food', 'Cat Litter', 'Cat Accessories', 'Cat Toys'],
#  'cat food': ['Dry Cat Food',
#   'Wet Cat Food',
#   'Cat Treats',
#   'Frozen Cat Food',
#   'Chilled Cat Food'],
#  'condoms': ['Large Condoms', 'Regular Condoms'],
#  'cookies': ['Chocolate Cookies',
#   'Mini Cookies',
#   'Shortbread Cookies',
#   'Cookie Varieties',
#   'Ice Cream'],
#  'dog': ['Dog Food', 'Dog Accessories', 'Dog Toys'],
#  'dog food': ['Dog Treats',
#   'Dry Dog Food',
#   'Dog Biscuits',
#   'Wet Dog Food',
#   'Chilled Dog Food'],
#  'drinks': ['Water', 'Juice', 'Soft Drinks', 'Energy Drinks', 'Kombucha'],
#  'fish': ['Salmon',
#   'Prawns',
#   'Barramundi',
#   'Calamari',
#   'Fish Fillet',
#   'Crumbed Fish',
#   'Frozen Fish'],
#  'frozen': ['Frozen Meals',
#   'Frozen Snacks & Pizza',
#   'Frozen Chips',
#   'Frozen Vegetables',
#   'Frozen Fruit',
#   'Ice Cream & Desserts',
#   'Frozen Seafood',
#   'Frozen Chicken',
#   'Bulk Range',
#   'Single Serve Meals'],
#  'huggies': ['Nappies',
#   'Wipes',
#   'Nappy Pants',
#   'Newborn - Size 2',
#   'Size 3',
#   'Size 4',
#   'Size 5',
#   'Size 6'],
#  'lamb': ['Lamb Shoulder', 'Lamb Roast', 'Lamb Shanks & Cutlets'],
#  'laundry': ['Laundry Detergent Liquid',
#   'Laundry Powder',
#   'Laundry Capsules',
#   'Fabric Softener',
#   'Stain Remover',
#   'Laundry Sheets'],
#  'makeup': ['Face', 'Eyes', 'Lips', 'Nails & Lashes', 'Tools & Accessories'],
#  'mco': ['Fragrance and Body',
#   'Face',
#   'Eyes',
#   'Lips',
#   'Skincare',
#   'Tools & Brushes',
#   'Nails & Lashes',
#   'Hair Accessories'],
#  'mco beauty': ['Fragrance and Body',
#   'Face',
#   'Eyes',
#   'Lips',
#   'Skincare',
#   'Tools & Brushes',
#   'Nails & Lashes',
#   'Hair Accessories'],
#  'mcobeauty': ['Fragrance and Body',
#   'Face',
#   'Eyes',
#   'Lips',
#   'Skincare',
#   'Tools & Brushes',
#   'Nails & Lashes',
#   'Hair Accessories'],
#  'meat': ['Chicken',
#   'Pork',
#   'Sausage',
#   'Mince',
#   'Beef',
#   'Steak',
#   'Lamb',
#   'Burger',
#   'Ham'],
#  'olive oil': ['Extra Virgin Olive Oil', 'Olive Oil Spray'],
#  'pads': ['Regular Pads', 'Super Pads', 'Overnight Pads'],
#  'pork': ['Pork Chops', 'Pork Belly', 'Bacon', 'Pork Mince', 'Pork Roast'],
#  'prawns': ['Raw Prawns', 'Cooked Prawns', 'Frozen Prawns', 'Garlic Prawns'],
#  'protein': ['Protein Yoghurt',
#   'Protein Bar',
#   'Protein Powder',
#   'Protein Drinks',
#   'Protein Snacks',
#   'Protein Pasta',
#   'Protein Meals'],
#  'protein bar': ['Muesli Bar',
#   'Nut Bar',
#   'Chocolate Protein Bar',
#   'Low Carb Protein Bar'],
#  'protein powder': ['Vanilla Protein Powder',
#   'Chocolate Protein Powder',
#   'Whey Protein Powder',
#   'Vegan Protein Powder',
#   'Plant Based Protein Powder'],
#  'ready meals': ['Pasta',
#   'Beef',
#   'Chicken',
#   'Soup',
#   'Quiche',
#   'Protein Meals',
#   'Single Serve Meals',
#   'Pies'],
#  'salmon': ['Smoked Salmon', 'Salmon Fillet', 'Canned Salmon'],
#  'seafood': ['Fresh Seafood',
#   'Salmon Fillet',
#   'Fish',
#   'Prawns',
#   'Frozen Seafood',
#   'Prepacked Seafood',
#   'Mixed Marinara',
#   'Crabs & Crustaceans'],
#  'shampoo': ['Anti Dandruff Shampoo',
#   'Purple Shampoo',
#   'Baby & Kids shampoo',
#   'Mens Shampoo',
#   'Dry Shampoo',
#   'Shampoo Bar',
#   'Conditioner',
#   'Shampoo & Conditioner'],
#  'stir fry': ['Stir Fry Vegetables',
#   'Stir Fry Sauce',
#   'Stir Fry Noodles',
#   'Stir Fry Meat'],
#  'sunscreen': ['Kids Sunscreen',
#   'Face Sunscreen',
#   'Sensitive Sunscreen',
#   'Body Sunscreen',
#   'Zinc'],
#  'tea': ['Green Tea',
#   'Black Tea',
#   'Chai',
#   'Peppermint Tea',
#   'Herbal Tea',
#   'Loose Leaf']}

# %%
# Out:
# dict_values([['Wipes', 'Bottles', 'Teething & Soothers', 'Bath & Skincare', 'Baby Health & Safety', 'Baby Toys', 'Baby Bibs'], ['0 - 6 months', '6-12 months', '12 months plus'], ['Diced Bacon', 'Streaky Bacon', 'Shortcut Bacon', 'Middle Bacon'], ['Pancake Mix', 'Chocolate Chips', 'Cooking Chocolate', 'Bread Mix', 'Brownie Mix', 'Cookie Mix', 'Muffin Mix', 'Cake Decorations', 'Colours & Essences'], ['Crackers', 'Cookies', 'Chocolate Biscuits', 'Shortbread', 'Crispbread', 'Wafer Biscuits'], ['White Bread', 'Wholegrain Bread', 'Turkish Bread', 'Banana Bread', 'Raisin Toast'], ['Butter & Margarine', 'Unsalted Butter', 'Salted Butter', 'Spreadable Butter'], ['Wipes', 'Baby Food', 'Nappies', 'Nappy Pants', 'Baby & Toddler Snacks', 'Baby Formula'], ['Organic Food', 'Baby Food 4 Months+', 'Baby Food 6 Months+', 'Baby Food 8 Months+', 'Baby & Toddler Snacks', 'Baby Formula'], ['Mince', 'Steak', 'Diced & Strips', 'Sausages & Burgers', 'Stock'], ['Multipacks'], ['Bread Rolls', 'Garlic Bread'], ['Nut Butters'], ['Oats', 'Bran'], ['Cheese Slices', 'Cream Cheese', 'Cheese Block', 'Cottage Cheese', 'Snacking Cheese', 'Shredded Cheese', 'Light Cheese'], ['Chicken Breast', 'Chicken Thigh', 'Chicken Mince', 'Chicken Tenders', 'Chicken Nuggets', 'Chicken Wings', 'Chicken Drumsticks', 'Chicken Kebabs', 'Chicken Kievs'], ['Frozen Chips', 'Corn Chips', 'Potato Chips'], ['Coffee Pods', 'Coffee Beans', 'Instant Coffee', 'Coffee Sachets', 'Ground Coffee', 'Decaf Coffee'], ['Sour Cream', 'Whipped Cream', 'Cooking Cream'], ['Cake Mix', 'Birthday Cake', 'Mud Cake', 'Chocolate Cake', 'Cheesecake', 'Sponge Cake', 'Cupcake'], ['Cake Mix', 'Birthday Cake', 'Mud Cake', 'Chocolate Cake', 'Cheesecake', 'Sponge Cake', 'Cupcake'], ['Multipack'], ['Chocolate Blocks', 'Chocolate Bars', 'Boxed Chocolate', 'Chocolate Minis', 'Dark Chocolate', 'Milk Chocolate', 'Chocolate Share Packs', 'Cooking Chocolate', 'Gift Packs'], ['Decorations', 'Chocolate', 'Stocking & Advent Calendars', 'Pudding', 'Cake', 'Candy Canes & Lollies', 'Christmas Lights', 'Christmas Tree', 'Ham'], ['Specialty'], ['6 Pack', '12 Pack', 'Family Pack'], ['Free Range'], ['Plain Flour', 'Self Raising Flour', 'Wholemeal Flour', 'Spelt Flour'], ['Pasta', 'Beef', 'Chicken', 'Kids Meals', 'Pies', 'Asian', 'Pies & Sausage Rolls', 'Pizza', 'Single Serve Meals'], ['Shaved & Shredded Ham', 'Sliced Ham', 'Deli Ham', 'Leg Ham', 'Champagne Ham', 'Honey Ham', 'Smoked Ham', 'English Ham'], ['Icecream Cones & Sticks', 'Vanilla', 'Chocolate', 'Strawberry', 'Icecream Tubs'], ['Vanilla Ice Cream', 'Chocolate Ice Cream', 'Ice Cream Cones', 'Ice Cream Tubs', 'Ice Cream Cakes', 'Sandwiches', 'Minis & Bites'], ['Fruit Juice', 'Juice Poppers', 'Vegetable Juice'], ['Sour Lollies', 'Liquorice'], ['Snakes', 'Party Mix', 'Family Size', 'Lollipops'], ['Almond Milk', 'Coconut Milk', 'Oat Milk', 'Skim Milk', 'Condensed Milk', 'Rice Milk', 'Full Fat'], ['Beef Mince', 'Pork Mince', 'Chicken Mince', 'Turkey Mince', 'Lean Beef Mince'], ['Whole Egg', 'Japanese', 'Light', 'Aioli', 'Traditional'], ['Pasta', 'Beef', 'Chicken', 'Soup', 'Quiche', 'Family Meals', 'Pizza', 'Single Serve Meals', 'Pies'], ['Long Life'], ['Bundles', 'Newborn', 'Size 2', 'Size 3', 'Size 4', 'Size 5', 'Size 6', 'Nappy Pants', 'Swim Nappies', 'Night Time Nappies'], ['Cup', 'Instant', 'Vermicelli & Rice Noodles', 'Udon Noodles', 'Ramen Noodles'], ['Muesli', 'Granola', 'Rolled Oats', 'Quick Oats', 'Clusters', 'Oat Sachets'], ['Olive Oil', 'Vegetable Oil', 'Canola Oil', 'Flavoured', 'Spray', 'Sesame Oil', 'Peanut Oil', 'Rice Bran Oil', 'Coconut Oil'], ['Pasta Sauce', 'Fresh Pasta'], ['Pizza Base', 'Pizza Sauce', 'Frozen Pizza'], ['Spaghetti', 'Spiral', 'Penne', 'Fettuccine', 'Macaroni', 'Rigatoni'], ['Brown Rice', 'Basmati Rice', 'Jasmine Rice', 'Microwave Rice', 'White Rice', 'Long Grain Rice'], ['Pasta', 'Beef', 'Chicken', 'Soup', 'Quiche', 'Family Meals', 'Pizza', 'Single Serve Meals', 'Pies'], ['Vegetable Rice'], ['Beef Sausages', 'Pork Sausages', 'Chicken Sausages ...

# %%
##PRODUCTS DATA 
query = '''
SELECT article as product_nbr, * EXCEPT (article) FROM `gcp-wow-rwds-ai-search-dev.14_elastic.keyword_to_product_price_BUP-MVP` 
WHERE kw = "milk";
'''
client = bigquery.Client()
data = client.query(query).to_dataframe()

# %%
def get_products(original_term, facet_names, threshold = 0.65):
    products = get_retrieval_produts(facet_names, score_threshold = threshold)
    
    df = products[["kw","product_nbr"]]
    df["original_term"] = original_term
    return df

# %%
d = get_products("MILK", result_dict["MILK"])

# %%
df = pd.DataFrame()
for i in result_dict:
    products = get_products(i, result_dict[i])
    df =  pd.concat([df, products], ignore_index=True)

# %%
import pandas as pd
from pandas_gbq import to_gbq


# Define your BigQuery project ID and dataset/table name
project_id = 'gcp-wow-rwds-ai-search-dev'  # Replace with your project ID
dataset_name = '99_temp'  # Replace with your BigQuery dataset
table_name = 'facets_products_hackathon'  # Replace with your BigQuery table name

# Move the DataFrame to BigQuery
to_gbq(df, f'{dataset_name}.{table_name}', project_id=project_id, if_exists='replace')

print(f"DataFrame has been uploaded to BigQuery table: {dataset_name}.{table_name}")
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 7319.90it/s]
# DataFrame has been uploaded to BigQuery table: 99_temp.facets_products_hackathon

# %%
results = pd.DataFrame()
for i in result_dict["MILK"]:
    d = get_retrieval_produts([i])
    print(i, d.shape)
    results = pd.concat([results, d], ignore_index = True)
# Out:
# Almond Milk (138, 3)
# Coconut Milk (134, 3)
# Oat Milk (75, 3)
# Skim Milk (48, 3)
# Condensed Milk (15, 3)
# Rice Milk (45, 3)
# Full Fat (1, 3)

# %%
# Out:
# ['Almond Milk',
#  'Coconut Milk',
#  'Oat Milk',
#  'Skim Milk',
#  'Condensed Milk',
#  'Rice Milk',
#  'Full Fat']

# %%
data[data.product_nbr == "761604"]
# Out:
#     product_nbr    kw      ctgry                      subcat  \
# 476      761604  milk  BEVERAGES       LONGLIFE MILK - PLANT
# 477      761604  milk  BEVERAGES  LONGLIFE MILK & SOY DRINKS
#
#                     sgmnt article_with_uom  \
# 476  LONG LIFE MILK - NUT        761604-EA
# 477  LONG LIFE MILK - NUT        761604-EA
#
#                                  product_name  similarity  similarity_safe  \
# 476  Almond Breeze Unsweetened Almond Milk 1l    0.497271          0.96264
# 477  Almond Breeze Unsweetened Almond Milk 1l    0.497271          0.96264
#
#      click_count    avg_price  sgmnt_price_scale  kw_price_scale product_type
# 476        13614  2.853934180           0.114286        0.359533          WOW
# 477        13614  2.949082638           0.081967        0.374708          WOW
